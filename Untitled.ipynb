# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name: __Scott Okamura__
# * Student pace: ___self paced___ / part time / full time
# * Scheduled project review date/time:
# * Instructor name: __Jeff Herman__
# * Blog post URL:

# %%
ls
# Out:
# 2020_LoL_esports_match_data_from_OraclesElixir_20201006.csv
# CONTRIBUTING.md
# LICENSE.md
# README.md
# Untitled.ipynb
# module_3_project_rubric.pdf
# smart.gif
# student.ipynb

# %%
import pandas as pd

df = pd.read_csv('2020_LoL_esports_match_data_from_OraclesElixir_20201006.csv')

df.head()
# Out:
#                   gameid datacompleteness  \
# 0  ESPORTSTMNT03/1241318         complete
# 1  ESPORTSTMNT03/1241318         complete
# 2  ESPORTSTMNT03/1241318         complete
# 3  ESPORTSTMNT03/1241318         complete
# 4  ESPORTSTMNT03/1241318         complete
#
#                                                  url league  year split  \
# 0  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 1  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 2  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 3  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
# 4  http://matchhistory.na.leagueoflegends.com/en/...  KeSPA  2020   NaN
#
#    playoffs                 date  game  patch  ...  csdiffat10 goldat15  \
# 0         0  2020-01-03 07:33:26     1   9.24  ...        23.0   4888.0
# 1         0  2020-01-03 07:33:26     1   9.24  ...       -10.0   4385.0
# ...

# %%
df.shape
# Out:
# (69324, 105)

# %%
df['league'].value_counts()
# Out:
# LDL      11508
# LPL       8712
# LCK       5676
# VCS       3660
# CK        3624
# PCS       3264
# LCS       3168
# EM        3120
# LEC       2892
# OPL       2604
# LCS.A     2580
# TCL       2436
# CBLOL     2352
# TRA       2184
# LFL       1992
# LJL       1980
# LLA       1908
# BRCC      1680
# LCL       1512
# WCS        996
# OCS        816
# MSC        300
# Riot       240
# KeSPA      120
# Name: league, dtype: int64

# %%
df['playoffs'].value_counts()
# Out:
# 0    60264
# 1     9060
# Name: playoffs, dtype: int64

# %%
df1 = df[df['playoffs'] == 1]

# %%
df1['league'].value_counts()
# Out:
# PCS      948
# LCS      948
# LPL      732
# LEC      732
# LJL      612
# LFL      588
# OPL      588
# LDL      504
# TCL      468
# VCS      432
# LCS.A    420
# LCK      324
# LLA      324
# CBLOL    276
# BRCC     264
# CK       252
# TRA      252
# LCL      228
# OCS      168
# Name: league, dtype: int64

# %%
df1['split'].value_counts()
# Out:
# Summer     4140
# Spring     2784
# Split 2     444
# Split 1     420
# Winter      216
# Closing     168
# Opening     156
# Name: split, dtype: int64

# %%
df1.groupby(['split', 'league']).describe()
# Out:
#                  year                                                       \
#                 count    mean  std     min     25%     50%     75%     max
# split   league
# Closing LLA     168.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
# Opening LLA     156.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
# Split 1 CBLOL   108.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
#         OPL     312.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
# Split 2 CBLOL   168.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
#         OPL     276.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
# Spring  CK      132.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
#         LCK     180.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
#         LCL     108.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
#         LCS     372.0  2020.0  0.0  2020.0  2020.0  2020.0  2020.0  2020.0
# ...

# %%
df2 = df1[df1['split'] == 'Summer']

# %%
df2['league'].value_counts()
# Out:
# LCS      576
# LDL      504
# PCS      468
# VCS      372
# LEC      360
# LPL      360
# LJL      300
# TCL      252
# LFL      216
# LCS.A    216
# LCK      144
# TRA      132
# LCL      120
# CK       120
# Name: league, dtype: int64

# %%
list(df2.columns)
# Out:
# ['gameid',
#  'datacompleteness',
#  'url',
#  'league',
#  'year',
#  'split',
#  'playoffs',
#  'date',
#  'game',
#  'patch',
#  'playerid',
#  'side',
#  'position',
#  'player',
#  'team',
#  'champion',
#  'ban1',
#  'ban2',
#  'ban3',
#  'ban4',
#  'ban5',
#  'gamelength',
#  'result',
#  'kills',
#  'deaths',
#  'assists',
#  'teamkills',
#  'teamdeaths',
#  'doublekills',
#  'triplekills',
#  'quadrakills',
#  'pentakills',
#  'firstblood',
#  'firstbloodkill',
#  'firstbloodassist',
#  'firstbloodvictim',
#  'team kpm',
#  'ckpm',
#  'firstdragon',
#  'dragons',
#  'opp_dragons',
#  'elementaldrakes',
#  'opp_elementaldrakes',
#  'infernals',
#  'mountains',
#  'clouds',
#  'oceans',
#  'dragons (type unknown)',
#  'elders',
#  'opp_elders',
#  'firstherald',
#  'heralds',
#  'opp_heralds',
#  'firstbaron',
#  'barons',
#  'opp_barons',
#  'firsttower',
#  'towers',
#  'opp_towers',
#  'firstmidtower',
#  'firsttothreetowers',
#  'inhibitors',
#  'opp_inhibitors',
# ...

# %%
pd.options.display.max_rows = 40
pd.options.display.max_columns = 40

# %%
df2['champion'].value_counts()
# Out:
# Ashe            189
# Renekton        146
# Graves          126
# Nautilus        119
# Sett            106
# Senna           101
# Volibear         98
# Jhin             97
# Ornn             95
# Caitlyn          86
# Orianna          85
# Thresh           83
# Zoe              82
# Ezreal           81
# Nidalee          79
# Leona            77
# Lillia           74
# Azir             73
# Bard             64
# Lucian           63
# Camille          63
# Syndra           62
# Lee Sin          59
# Akali            57
# Twisted Fate     50
# Gangplank        47
# Braum            47
# Tahm Kench       47
# Shen             46
# Kalista          44
# Galio            42
# Jayce            41
# Mordekaiser      41
# Pantheon         39
# Karma            38
# Lux              35
# Morgana          33
# Hecarim          33
# Olaf             31
# Kindred          29
# Aphelios         28
# Trundle          27
# Wukong           27
# LeBlanc          25
# Rakan            25
# ...

# %%
df2['result'].value_counts()
# Out:
# 1    2070
# 0    2070
# Name: result, dtype: int64

# %%
df2['datacompleteness'].value_counts()
# Out:
# complete    4056
# partial       84
# Name: datacompleteness, dtype: int64

# %%
leagues = ['LCK','LPL','LCS','LEC','PCS']

df3 = df2.loc[(df2['league'] == 'LCK') | (df2['league'] == 'LPL') |
        (df2['league'] == 'LCS') | (df2['league'] == 'LEC') |
        (df2['league'] == 'PCL')]

# %%
df3.shape
# Out:
# (1440, 105)

# %%
df3.head()
# Out:
#           gameid datacompleteness  \
# 59196  6680-8803         complete
# 59197  6680-8803         complete
# 59198  6680-8803         complete
# 59199  6680-8803         complete
# 59200  6680-8803         complete
#
#                                                url league  year   split  \
# 59196  https://lpl.qq.com/es/stats.shtml?bmid=6680    LPL  2020  Summer
# 59197  https://lpl.qq.com/es/stats.shtml?bmid=6680    LPL  2020  Summer
# 59198  https://lpl.qq.com/es/stats.shtml?bmid=6680    LPL  2020  Summer
# 59199  https://lpl.qq.com/es/stats.shtml?bmid=6680    LPL  2020  Summer
# 59200  https://lpl.qq.com/es/stats.shtml?bmid=6680    LPL  2020  Summer
#
#        playoffs                 date  game  patch  playerid  side position  \
# 59196         1  2020-08-13 09:20:00     1  10.16         1  Blue      top
# 59197         1  2020-08-13 09:20:00     1  10.16         2  Blue      jng
# 59198         1  2020-08-13 09:20:00     1  10.16         3  Blue      mid
# ...

# %%
for x in df3.columns:
    print(df3[x].value_counts(normalize=True))
    print("\n\n")
# Out:
# ESPORTSTMNT03/1441725    0.008403
# ESPORTSTMNT03/1432289    0.008403
# ESPORTSTMNT06/1320442    0.008403
# ESPORTSTMNT06/1320892    0.008403
# 6682-8833                0.008403
#                            ...
# ESPORTSTMNT03/1433008    0.008403
# ESPORTSTMNT06/1310719    0.008403
# 6680-8806                0.008403
# ESPORTSTMNT06/1320895    0.008403
# ESPORTSTMNT06/1310864    0.008403
# Name: gameid, Length: 119, dtype: float64
#
#
#
# complete    0.958333
# partial     0.041667
# Name: datacompleteness, dtype: float64
#
#
#
# https://lpl.qq.com/es/stats.shtml?bmid=6686                                                                     0.041667
# https://lpl.qq.com/es/stats.shtml?bmid=6681                                                                     0.033333
# https://lpl.qq.com/es/stats.shtml?bmid=6680                                                                     0.033333
# ...
